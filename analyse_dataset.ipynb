# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
# Load DataFrame
df = pd.read_pickle("database_reference_MLREADY.pkl")

# Sort by LABEL count
value_counts = df['LABEL'].value_counts()
df = df.set_index('LABEL').loc[value_counts.index].reset_index()

# Clean up some minor spelling mistakes
df["Device"] = df["Device"].str.replace("olympus sz61 + olympus dp23", "Olympus SZ61 + Olympus DP23")
df["Device"] = df["Device"].str.replace("macrolens + iphone se", "Macrolens + iPhone SE")
df["Device"] = df["Device"].str.replace('leica-m205c', 'Leica-M205C')
df["Device"] = df["Device"].str.replace('leica m205c + leica k/3c', 'Leica-M205C')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Load DataFrame
# ----> 2 df = pd.read_pickle("database_reference_MLREADY.pkl")
#       4 # Sort by LABEL count
#       5 value_counts = df['LABEL'].value_counts()
#
# File ~/fuck/lib/python3.10/site-packages/pandas/io/pickle.py:185, in read_pickle(filepath_or_buffer, compression, storage_options)
#     123 """
#     124 Load pickled pandas object (or any object) from file.
#     125
#    (...)
#     182 4    4    9
#     183 """
#     184 excs_to_catch = (AttributeError, ImportError, ModuleNotFoundError, TypeError)
# --> 185 with get_handle(
#     186     filepath_or_buffer,
#     187     "rb",
#     188     compression=compression,
#     189     is_text=False,
#     190     storage_options=storage_options,
#     191 ) as handles:
#     192     # 1) try standard library Pickle
# ...

# %%
# Latex List fro Figure 1
species_list_latex_sorted = [
    '$\\it{Cx. torrentium-pipiens\\ }$s.l. pair',
    '$\\it{Ae. aegypti}$',
    '$\\it{Ae. albopictus}$',
    '$\\it{Ae. japonicus}$',
    '$\\it{Ae. koreicus}$',
    "other",
    '$\\it{An. maculipennis}$ s.l.',
    '$\\it{Cx. vishnui}$-group',
    '$\\it{Ae. communis-punctor\\ }$pair',
    '$\\it{Ae. vexans}$',
    '$\\it{Ae. cinereus-geminus\\ }$pair',
    '$\\it{Ae. annulipes}$-group',
    '$\\it{An. stephensi}$',
    '$\\it{Ae. sticticus}$',
    '$\\it{Ae. rusticus}$',
    '$\\it{Cs. morsitans-fumipennis\\ }$pair',
    '$\\it{Cx. modestus}$',
    '$\\it{Ae. cataphylla}$',
    '$\\it{An. claviger - petragnani\\ }$pair',
    '$\\it{Cq. richiardii}$',
    '$\\it{Ae. caspius}$',
    ]

# %%
# Get the number of unique specimens
df["Specimen ID"].nunique()
# Out:
# 8947

# %%
# Find the percentage of mosquito samples which have both wings in the dataset (L and R)
both_wings_count = df.groupby('Specimen ID')['Wing side'].nunique().eq(2).sum()
total_specimens = df['Specimen ID'].nunique()
percentage_both_wings = (both_wings_count / total_specimens) * 100
percentage_both_wings
# Out:
# 48.16139488096569

# %%
# Find the percentage of mosquito samples which have been captured with multiple devices
both_device_count = df.groupby(['Specimen ID', "Wing side"])['Device'].nunique().eq(2).sum()
total_specimens = 13256
percentage_both_wings = (both_device_count / total_specimens) * 100
percentage_both_wings
# Out:
# 11.217561858780929

# %%
# Figure 1
fig, ax = plt.subplots(2,1, figsize=(16,7), sharex=True)

a = sb.histplot(df, x="LABEL", color="dimgrey", edgecolor="white", alpha=1, ax=ax[0], fill=True)
b = sb.histplot(df, x="LABEL", hue="Device", edgecolor="white" , palette=["#802823", "#A27942", "#326F32"], multiple="fill", alpha=.8, ax=ax[1])

ax[0].yaxis.grid(True, which='major', linestyle='dotted', linewidth=.75)
ax[0].set_axisbelow(True)
ax[0].spines[['right', 'top']].set_visible(False)
ax[0].set_ylabel("Number of Images")

ax[1].yaxis.grid(True, which='major', linestyle='dotted', linewidth=.75)
ax[1].set_axisbelow(True)
ax[1].set_xlabel("")
ax[1].tick_params(axis='x', labelrotation=90)
ax[1].set_xticklabels(species_list_latex_sorted)
ax[1].set_ylabel("Proportion of Device [%]")
ax[1].set_yticks([0, .25, .5, .75, 1])
ax[1].set_yticklabels(["0", "25", "50", "75", "100"])
ax[1].spines[['right', 'top']].set_visible(False)
plt.tight_layout()
sb.move_legend(b, "lower center", bbox_to_anchor=(.15, -1.15), title="", ncol=1,  frameon=False)
plt.savefig("figures/figure_1.svg", dpi=300)
# Out:
# /var/folders/zq/vkd6f9tx4gdctwbs4b3j895w0000gn/T/ipykernel_79754/1321512096.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(species_list_latex_sorted)

# %%
# I want visualize the a dataset which is split into six folds with a 5-fold cross-validation
prop = 1/6
fig, ax = plt.subplots(2, figsize=(16,7))
ax[0].barh(0,1, label="Complete Dataset", color="dimgrey")
ax[0].barh(-1,prop, left=prop*5,label="Fold 5", color="#4B7D9C", edgecolor="white", alpha=.8)
ax[0].barh(-1,prop, left=prop*4,label="Fold 4", color="#1E4E79", edgecolor="white", alpha=.8)
ax[0].barh(-1,prop, left=prop*3,label="Fold 3", color="#326F32", edgecolor="white", alpha=.8)
ax[0].barh(-1,prop, left=prop*2,label="Fold 2", color="#A27942", edgecolor="white", alpha=.8)
ax[0].barh(-1,prop, left=prop*1,label="Fold 1", color="#802823", edgecolor="white", alpha=.8)
ax[0].barh(-1,prop, left=0, label="Fold 0 (Validation)", color="#9E9E9E", edgecolor="white", alpha=.8)

# Add labels on bars
for i, label in enumerate(["Fold 0 (Validation)", "Fold 1", "Fold 2", "Fold 3", "Fold 4", "Fold 5"]):
    ax[0].text(prop*i + prop/2, -1, label, ha='center', va='center', color='white', fontsize=12)

ax[0].set_yticks([0, -1])
ax[0].set_yticklabels(["Dataset", "Folds"], fontsize=12)

ax[0].set_xticks([0.25,0.5,0.75,1])
ax[0].set_xticklabels(["25%", "50%", "75%", "100%"], fontsize=12)
#turn all spines but the left one of
ax[0].spines['right'].set_visible(False)
ax[0].spines['top'].set_visible(False)

#ax[0].legend(title="Fold", loc="center", bbox_to_anchor=(.5, .5), frameon=False)
#Validation Fold
ax[1].barh(0,prop*5, left=prop*1.5, color="white", edgecolor="dimgrey", alpha=.8, linewidth=4)
ax[1].barh(0,prop, left=0, color="white", edgecolor="dimgrey", alpha=.8, linewidth=4)

ax[1].barh(0,prop, left=prop*5.5,label="Fold 5", color="#4B7D9C", edgecolor="white", alpha=.8)
ax[1].barh(0,prop, left=prop*4.5,label="Fold 4", color="#1E4E79", edgecolor="white", alpha=.8)
ax[1].barh(0,prop, left=prop*3.5,label="Fold 3", color="#326F32", edgecolor="white", alpha=.8)
ax[1].barh(0,prop, left=prop*2.5,label="Fold 2", color="#A27942", edgecolor="white", alpha=.8)
ax[1].barh(0,prop, left=prop*1.5,label="Fold 1", color="#802823", edgecolor="white", alpha=.8)
ax[1].barh(0,prop, left=0, label="Fold 0 (Validation)", color="#9E9E9E", edgecolor="white", alpha=.8)

# First Fold
ax[1].barh(-1,prop*5, left=prop*1.5, color="white", edgecolor="dimgrey", alpha=.8, linewidth=4)
ax[1].barh(-1,prop, left=0, color="white", edgecolor="dimgrey", alpha=.8, linewidth=4)

ax[1].barh(-1,prop, height=.8, left=prop*5.5,label="Fold 5", color="#4B7D9C", edgecolor="white", alpha=.8)
ax[1].barh(-1,prop, left=prop*4.5,label="Fold 4", color="#1E4E79", edgecolor="white", alpha=.8)
ax[1].barh(-1,prop, left=prop*3.5,label="Fold 3", color="#326F32", edgecolor="white", alpha=.8)
ax[1].barh(-1,prop, left=prop*2.5,label="Fold 2", color="#A27942", edgecolor="white", alpha=.8)
ax[1].barh(-1,prop, left=prop*1.5,label="Fold 0 (Validation)", color="#9E9E9E", edgecolor="white", alpha=.8)
ax[1].barh(-1,prop, left=0, label="Fold 1", color="#802823", edgecolor="white", alpha=.8)

# Last Fold
ax[1].barh(-2.5,prop*5, left=prop*1.5, color="white", edgecolor="dimgrey", alpha=.8, linewidth=4)
ax[1].barh(-2.5,prop, left=0, color="white", edgecolor="dimgrey", alpha=.8, linewidth=4)

ax[1].barh(-2.5,prop, left=prop*5.5,label="Fold 4", color="#1E4E79", edgecolor="white", alpha=.8)
ax[1].barh(-2.5,prop, left=prop*4.5,label="Fold 3", color="#326F32", edgecolor="white", alpha=.8)
ax[1].barh(-2.5,prop, left=prop*3.5,label="Fold 2", color="#A27942", edgecolor="white", alpha=.8)
ax[1].barh(-2.5,prop, left=prop*2.5,label="Fold 1", color="#802823", edgecolor="white", alpha=.8)
ax[1].barh(-2.5,prop, left=prop*1.5,label="Fold 0 (Validation)", color="#9E9E9E", edgecolor="white", alpha=.8)
ax[1].barh(-2.5,prop, left=0, label="Fold 5", color="#4B7D9C", edgecolor="white", alpha=.8)

ax[1].set_xticks([0.075, 0.66])
ax[1].set_xticklabels(["Testing", "Training"], fontsize=12)
ax[1].set_xlim(-0.005,1.14)

ax[1].set_yticks([0, -1, -2.5])
ax[1].set_yticklabels(["Validation", "Training Run 1", "Training Run 5"], fontsize=12)

ax[1].spines['right'].set_visible(False)
ax[1].spines['top'].set_visible(False)

# annotate a "..." between the training runs
ax[1].text(.66, -1.73, "...", ha='center', va='center', color='black', fontsize=15, fontweight='bold')
plt.tight_layout()
plt.savefig("figures/figure_2.png", dpi=300)
